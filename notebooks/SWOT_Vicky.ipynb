# %% [markdown]
# SWOT_KaRIn_MIT_Cal/Val_Vesrsion1
#
# Short Name:
# SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1
#
# Collection Concept ID:
# C2147947806-POCLOUD
#
# https://podaac.jpl.nasa.gov/dataset/SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1?ids&values&search=swot%20simulated%20level-2&provider=POCLOUD

# %%
import s3fs
import os
import os.path
import json
import warnings
import requests
import numpy as np
import pandas as pd
import xarray as xr
from io import StringIO

import matplotlib.pyplot as plt
import matplotlib
from matplotlib.ticker import FormatStrFormatter
from matplotlib import ticker, rc, cm

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy

# import geoviews as gv
# import hvplot.xarray
# import holoviews as hv
# gv.extension('bokeh', 'matplotlib')

warnings.filterwarnings("ignore")

# %matplotlib inline
# %matplotlib qt5
# %matplotlib widget

# %% [markdown]
# ## Set some parameters (start/end time)

# %%
plt.rcParams['figure.figsize'] = (5,4)
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 400

savefig = True # set to true to save plots as file
# !mkdir ../plots

__figdir__ = '../plots/'
savefig_args = {'bbox_inches':'tight', 'pad_inches':0.2}
plotfiletype='png'
# Out:
# mkdir: cannot create directory ‘../plots’: File exists

# %% [markdown]
# ## PO DAAC Catalog exploration using the CMR API
#
# - The search is restricted to colections that have data over a given time window

# %%
provider = 'POCLOUD'
url = 'https://cmr.earthdata.nasa.gov/search/collections.umm_json'
response = requests.get(url,
                        params={
                            'cloud_hosted': 'True',
                            'has_granules': 'True',
                            'provider': provider,
                            'page_size': 500,
                            'temporal': ['2021-10-01T10:00:00Z','2021-11-01T00:00:00Z'] 
                        },
                        headers={
                            'Accept': 'application/json'
                        }
                       )
response.headers['cmr-hits']
# Out:
# '246'

# %% [markdown]
# ### Loop through each response in the catalog and print the respective concept ID
#
# These are the data sets that cover the time period of interest

# %%
#  This will show short names and concept ids for all PO.DAAC data sets at this time
if False:
    for r in response.json()['items']:
        print('{} ==> '.format(r['meta']['s3-links'][0].split('/')[1]), r['meta']['concept-id'])

# %% [markdown]
# ### Loading credentials for direct access

# %%
def begin_s3_direct_access(url: str="https://archive.podaac.earthdata.nasa.gov/s3credentials"):
    response = requests.get(url).json()
    return s3fs.S3FileSystem(key=response['accessKeyId'],
                             secret=response['secretAccessKey'],
                             token=response['sessionToken'],
                             client_kwargs={'region_name':'us-west-2'})

fs = begin_s3_direct_access()

type(fs)
# Out:
# s3fs.core.S3FileSystem

# %%
# Center location
#site = 'S-MODE'
site = 'S-MODE IOP1'
#site = 'SPURS-1'

if site == 'S-MODE':
    lon0 = -123.5
    lat0 = 37.5 
    dlon = 2.5 # half of box width in lon
    dlat = 1.5 # half of box width in lat
elif site == 'S-MODE IOP1':
    lon0 = -124.5
    lat0 = 37
    dlon = 2.5 # half of box width in lon
    dlat = 1.5 # half of box width in lat
elif site == 'SPURS-2':
    lon0 = -125
    lat0 = 10
    dlon = 1.5 # half of box width in lon
    dlat = 1.5 # half of box width in lat
elif site == 'SPURS-1':
    lon0 = -38
    lat0 = 25
    dlon = 1.5 # half of box width in lon
    dlat = 1.5 # half of box width in lat

# Define the max/min lon
lon_min = lon0 - dlon
lon_max = lon0 + dlon
lat_min = lat0 - dlat
lat_max = lat0 + dlat

# %%
'''# Define the max/min lon
lon_min = 0
lon_max = 360
lat_min = -90
lat_max = 90
'''
# Out:
# '# Define the max/min lon\nlon_min = 0\nlon_max = 360\nlat_min = -90\nlat_max = 90\n'

# %%
start_time = '2011-11-13T00:00:00Z'
end_time = '2012-11-12T00:00:00Z'

# %%
'''url = 'https://cmr.earthdata.nasa.gov/search/granules'

concept_id = 'C2152046451-POCLOUD'; shortname= 'SWOT_SIMULATED_L2_KARIN_SSH_GLORYS_CALVAL_V1'
response = requests.get(url, 
                        params={
                            'concept_id': concept_id,
                            'temporal': start_time+','+end_time,
                            'bounding_box': '{},{},{},{}'.format(lon_min, lat_min, lon_max, lat_max),    
                            'page_size': 500,
                            },
                        headers={
                            'Accept': 'application/json'
                            }
                       )
print(response)
print(response.headers['CMR-Hits'])'''
# Out:
# "url = 'https://cmr.earthdata.nasa.gov/search/granules'\n\nconcept_id = 'C2152046451-POCLOUD'; shortname= 'SWOT_SIMULATED_L2_KARIN_SSH_GLORYS_CALVAL_V1'\nresponse = requests.get(url, \n                        params={\n                            'concept_id': concept_id,\n                            'temporal': start_time+','+end_time,\n                            'bounding_box': '{},{},{},{}'.format(lon_min, lat_min, lon_max, lat_max),    \n                            'page_size': 500,\n                            },\n                        headers={\n                            'Accept': 'application/json'\n                            }\n                       )\nprint(response)\nprint(response.headers['CMR-Hits'])"

# %%
url = 'https://cmr.earthdata.nasa.gov/search/granules'

# VIIRS_NPP-OSPO-L2P-v2.61 ==>  C1996880725-POCLOUD

concept_id = 'C2147947806-POCLOUD'; shortname= 'SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1'
response = requests.get(url, 
                        params={
                            'concept_id': concept_id,
                            'temporal': start_time+','+end_time,
                            'bounding_box': '{},{},{},{}'.format(lon_min, lat_min, lon_max, lat_max),    
                            'page_size': 500,
                            },
                        headers={
                            'Accept': 'application/json'
                            }
                       )
print(response)
print(response.headers['CMR-Hits'])
# Out:
# <Response [200]>
# 736

# %%
granules_url = []
for gran in response.json()['feed']['entry']:
    granules_url.append(gran['links'][1]['href'])
# granules_url
len(granules_url)
print('Number of files found is ' + str(len(granules_url)))
if len(granules_url) == 500:
    print('Max number of files returned. There may be more files.  Try shortening time window.')
# Out:
# Number of files found is 500
# Max number of files returned. There may be more files.  Try shortening time window.

# %%
gran['links']#['rel'=='http://esipfed.org/ns/fedsearch/1.1/s3#'];
# Out:
# [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#   'title': 'Download SWOT_L2_LR_SSH_Expert_250_002_20120717T095511_20120717T104617_DG10_01.nc',
#   'hreflang': 'en-US',
#   'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1/SWOT_L2_LR_SSH_Expert_250_002_20120717T095511_20120717T104617_DG10_01.nc'},
#  {'rel': 'http://esipfed.org/ns/fedsearch/1.1/s3#',
#   'title': 'This link provides direct download access via S3 to the granule',
#   'hreflang': 'en-US',
#   'href': 's3://podaac-ops-cumulus-protected/SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1/SWOT_L2_LR_SSH_Expert_250_002_20120717T095511_20120717T104617_DG10_01.nc'},
#  {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#   'title': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#   'hreflang': 'en-US',
#   'href': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#  {'rel': 'http://esipfed.org/ns/fedsearch/1.1/service#',
#   'title': 'OPeNDAP request URL',
#   'hreflang': 'en-US',
#   'href': 'https://opendap.earthdata.nasa.gov/collections/C2147947806-POCLOUD/granules/SWOT_L2_LR_SSH_Expert_250_002_20120717T095511_20120717T104617_DG10_01'},
#  {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#   'type': 'image/png',
#   'hreflang': 'en-US',
#   'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1/SWOT_L2_LR_SSH_Expert_250_002_20120717T095511_20120717T104617_DG10_01.simulated_error_baseline_dilation.png'},
#  {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#   'type': 'image/png',
#   'hreflang': 'en-US',
#   'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1/SWOT_L2_LR_SSH_Expert_250_002_20120717T095511_20120717T104617_DG10_01.simulated_error_karin.png'},
#  {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#   'type': 'image/png',
#   'hreflang': 'en-US',
#   'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1/SWOT_L2_LR_SSH_Expert_250_002_20120717T095511_20120717T104617_DG10_01.simulated_error_orbital.png'},
#  {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#   'type': 'image/png',
#   'hreflang': 'en-US',
#   'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1/SWOT_L2_LR_SSH_Expert_250_002_20120717T095511_20120717T104617_DG10_01.simulated_error_phase.png'},
#  {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#   'type': 'image/png',
#   'hreflang': 'en-US',
#   'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1/SWOT_L2_LR_SSH_Expert_250_002_20120717T095511_20120717T104617_DG10_01.simulated_error_roll.png'},
#  {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#   'type': 'image/png',
#   'hreflang': 'en-US',
#   'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1/SWOT_L2_LR_SSH_Expert_250_002_20120717T095511_20120717T104617_DG10_01.simulated_error_timing.png'},
#  {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#   'type': 'image/png',
#   'hreflang': 'en-US',
#   'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1/SWOT_L2_LR_SSH_Expert_250_002_20120717T095511_20120717T104617_DG10_01.simulated_error_troposphere.png'},
#  {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#   'type': 'image/png',
#   'hreflang': 'en-US',
#   'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1/SWOT_L2_LR_SSH_Expert_250_002_20120717T095511_20120717T104617_DG10_01.ssh_karin_2.png'},
#  {'inherited': True,
#   'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#   'hreflang': 'en-US',
#   'href': 'https://podaac.jpl.nasa.gov/CitingPODAAC'},
#  {'inherited': True,
#   'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#   'hreflang': 'en-US',
#   'href': 'https://podaac.jpl.nasa.gov/SWOT'},
#  {'inherited': True,
#   'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#   'hreflang': 'en-US',
#   'href': 'https://github.com/podaac/data-readers'},
#  {'inherited': True,
#   'length': '2.1GB',
#   'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#   'hreflang': 'en-US',
#   'href': 'https://cmr.earthdata.nasa.gov/virtual-directory/collections/C2147947806-POCLOUD'},
#  {'inherited': True,
#   'length': '2.1GB',
#   'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#   'hreflang': 'en-US',
#   'href': 'https://search.earthdata.nasa.gov/search/granules?p=C2147947806-POCLOUD'},
#  {'inherited': True,
#   'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#   'hreflang': 'en-US',
#   'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-docs/web-misc/swot_mission_docs/pdd/D-56407_SWOT_Product_Description_L2_LR_SSH_20200806.pdf'},
#  {'inherited': True,
#   'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#   'hreflang': 'en-US',
#   'href': 'https://github.com/podaac/data-subscriber'}]

# %%
# This loads a single file
ds = xr.open_dataset(fs.open(granules_url[1]))

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                                (num_lines: 9868, num_pixels: 71,
#                                             num_sides: 2)
# Coordinates:
#     latitude                               (num_lines, num_pixels) float64 ...
#     longitude                              (num_lines, num_pixels) float64 ...
#     latitude_nadir                         (num_lines) float64 ...
#     longitude_nadir                        (num_lines) float64 ...
# Dimensions without coordinates: num_lines, num_pixels, num_sides
# Data variables: (12/92)
#     time                                   (num_lines) datetime64[ns] ...
#     time_tai                               (num_lines) datetime64[ns] ...
#     ssh_karin                              (num_lines, num_pixels) float64 ...
#     ssh_karin_uncert                       (num_lines, num_pixels) float32 ...
#     ssha_karin                             (num_lines, num_pixels) float64 ...
#     ssh_karin_2                            (num_lines, num_pixels) float64 ...
#     ...                                     ...
#     simulated_error_karin                  (num_lines, num_pixels) float64 ...
#     simulated_error_timing                 (num_lines, num_pixels) float64 ...
#     simulated_error_roll                   (num_lines, num_pixels) float64 ...
#     simulated_error_phase                  (num_lines, num_pixels) float64 ...
#     simulated_error_orbital                (num_lines, num_pixels) float64 ...
#     simulated_error_troposphere            (num_lines, num_pixels) float64 ...
# Attributes: (12/32)
#     Conventions:                CF-1.7
#     title:                      Level 2 Low Rate Sea Surface Height Data Prod...
#     institution:                CNES/JPL
#     source:                     Simulate product
#     history:                    2021-09-23 07:44:27Z : Creation
#     platform:                   SWOT
#     ...                         ...
#     right_last_longitude:       311.89957599684425
#     right_last_latitude:        77.03365811434979
#     wavelength:                 0.008385803020979
#     orbit_solution:             POE
#     ellipsoid_semi_major_axis:  6378137.0
#     ellipsoid_flattening:       0.0033528106647474805

# %%
np.squeeze(ds)
# Out:
# <xarray.Dataset>
# Dimensions:                                (num_lines: 9868, num_pixels: 71,
#                                             num_sides: 2)
# Coordinates:
#     latitude                               (num_lines, num_pixels) float64 ...
#     longitude                              (num_lines, num_pixels) float64 ...
#     latitude_nadir                         (num_lines) float64 ...
#     longitude_nadir                        (num_lines) float64 ...
# Dimensions without coordinates: num_lines, num_pixels, num_sides
# Data variables: (12/92)
#     time                                   (num_lines) datetime64[ns] ...
#     time_tai                               (num_lines) datetime64[ns] ...
#     ssh_karin                              (num_lines, num_pixels) float64 ...
#     ssh_karin_uncert                       (num_lines, num_pixels) float32 ...
#     ssha_karin                             (num_lines, num_pixels) float64 ...
#     ssh_karin_2                            (num_lines, num_pixels) float64 ...
#     ...                                     ...
#     simulated_error_karin                  (num_lines, num_pixels) float64 ...
#     simulated_error_timing                 (num_lines, num_pixels) float64 ...
#     simulated_error_roll                   (num_lines, num_pixels) float64 ...
#     simulated_error_phase                  (num_lines, num_pixels) float64 ...
#     simulated_error_orbital                (num_lines, num_pixels) float64 ...
#     simulated_error_troposphere            (num_lines, num_pixels) float64 ...
# Attributes: (12/32)
#     Conventions:                CF-1.7
#     title:                      Level 2 Low Rate Sea Surface Height Data Prod...
#     institution:                CNES/JPL
#     source:                     Simulate product
#     history:                    2021-09-23 07:44:27Z : Creation
#     platform:                   SWOT
#     ...                         ...
#     right_last_longitude:       311.89957599684425
#     right_last_latitude:        77.03365811434979
#     wavelength:                 0.008385803020979
#     orbit_solution:             POE
#     ellipsoid_semi_major_axis:  6378137.0
#     ellipsoid_flattening:       0.0033528106647474805

# %%
file_list =  [fs.open(file) for file in granules_url]

# %%
plt.figure(1)
ax = plt.axes(projection = ccrs.PlateCarree(central_longitude=-125))  # Orthographic
extent = [lon_min, lon_max,lat_min, lat_max]
#ax.set_extent(extent, crs=ccrs.PlateCarree())


plt.set_cmap(cmap=plt.get_cmap('turbo'))
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, alpha=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False
ax.set_title('Wind Speed', size = 10.)

ds = xr.open_dataset(file_list[10])
var = ds.wind_speed_model_u #simulated_true_ssh_karin
#plt.pcolor(ds.longitude, ds.latitude, var)
cs = ax.pcolormesh(ds.longitude,ds.latitude,var,transform=ccrs.PlateCarree())
cb = plt.colorbar(cs,fraction = 0.029,pad = 0.2,extend='both')
ax.coastlines()
ax.add_feature(cartopy.feature.LAND, zorder=3, facecolor=[.6,.6,.6], edgecolor='black')
#cs = ax.pcolormesh(ds.longitude,ds.latitude,ds.sea_surface_temperature.squeeze()-274.15,vmin=V[0],vmax=V[1],transform=ccrs.PlateCarree())
# cs = ax.pcolormesh(ds2.lon,ds2.lat,ds2.sea_surface_temperature.squeeze().notnull(),transform=ccrs.PlateCarree())
#cb = plt.colorbar(cs,fraction = 0.022,extend='both')
#cb.set_label('SST [$\circ$C]',fontsize = 10)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ds = xr.open_mfdataset(file_list, chunks='auto')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 ds = xr.open_mfdataset(file_list, chunks='auto')
#
# File ~/miniconda3/envs/aws/lib/python3.10/site-packages/xarray/backends/api.py:997, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     994     open_ = open_dataset
#     995     getattr_ = getattr
# --> 997 datasets = [open_(p, **open_kwargs) for p in paths]
#     998 closers = [getattr_(ds, "_close") for ds in datasets]
#     999 if preprocess is not None:
#
# File ~/miniconda3/envs/aws/lib/python3.10/site-packages/xarray/backends/api.py:997, in <listcomp>(.0)
#     994     open_ = open_dataset
#     995     getattr_ = getattr
# --> 997 datasets = [open_(p, **open_kwargs) for p in paths]
#     998 closers = [getattr_(ds, "_close") for ds in datasets]
#     999 if preprocess is not None:
#
# File ~/miniconda3/envs/aws/lib/python3.10/site-packages/xarray/backends/api.py:546, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     539 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
#     540 backend_ds = backend.open_dataset(
#     541     filename_or_obj,
#     542     drop_variables=drop_variables,
#     543     **decoders,
#     544     **kwargs,
#     545 )
# --> 546 ds = _dataset_from_backend_dataset(
#     547     backend_ds,
#     548     filename_or_obj,
#     549     engine,
#     550     chunks,
#     551     cache,
#     552     overwrite_encoded_chunks,
#     553     inline_array,
#     554     drop_variables=drop_variables,
#     555     **decoders,
#     556     **kwargs,
#     557 )
#     558 return ds
#
# File ~/miniconda3/envs/aws/lib/python3.10/site-packages/xarray/backends/api.py:358, in _dataset_from_backend_dataset(backend_ds, filename_or_obj, engine, chunks, cache, overwrite_encoded_chunks, inline_array, **extra_tokens)
#     356     ds = backend_ds
#     357 else:
# --> 358     ds = _chunk_ds(
#     359         backend_ds,
#     360         filename_or_obj,
#     361         engine,
#     362         chunks,
#     363         overwrite_encoded_chunks,
#     364         inline_array,
#     365         **extra_tokens,
#     366     )
#     368 ds.set_close(backend_ds._close)
#     370 # Ensure source filename always stored in dataset object
#
# File ~/miniconda3/envs/aws/lib/python3.10/site-packages/xarray/backends/api.py:326, in _chunk_ds(backend_ds, filename_or_obj, engine, chunks, overwrite_encoded_chunks, inline_array, **extra_tokens)
#     324 variables = {}
#     325 for name, var in backend_ds.variables.items():
# --> 326     var_chunks = _get_chunk(var, chunks)
#     327     variables[name] = _maybe_chunk(
#     328         name,
#     329         var,
#    (...)
#     334         inline_array=inline_array,
#     335     )
#     336 return backend_ds._replace(variables)
#
# File ~/miniconda3/envs/aws/lib/python3.10/site-packages/xarray/core/dataset.py:221, in _get_chunk(var, chunks)
#     216     chunks = dict.fromkeys(dims, chunks)
#     217 chunk_shape = tuple(
#     218     chunks.get(dim, None) or preferred_chunk_sizes
#     219     for dim, preferred_chunk_sizes in zip(dims, preferred_chunk_shape)
#     220 )
# --> 221 chunk_shape = da.core.normalize_chunks(
#     222     chunk_shape, shape=shape, dtype=var.dtype, previous_chunks=preferred_chunk_shape
#     223 )
#     225 # Warn where requested chunks break preferred chunks, provided that the variable
#     226 # contains data.
#     227 if var.size:
#
# File ~/miniconda3/envs/aws/lib/python3.10/site-packages/dask/array/core.py:3073, in normalize_chunks(chunks, shape, limit, dtype, previous_chunks)
#    3070 chunks = tuple("auto" if isinstance(c, str) and c != "auto" else c for c in chunks)
#    3072 if any(c == "auto" for c in chunks):
# -> 3073     chunks = auto_chunks(chunks, shape, limit, dtype, previous_chunks)
#    3075 if shape is not None:
#    3076     chunks = tuple(c if c not in {None, -1} else s for c, s in zip(chunks, shape))
#
# File ~/miniconda3/envs/aws/lib/python3.10/site-packages/dask/array/core.py:3169, in auto_chunks(chunks, shape, limit, dtype, previous_chunks)
#    3166     raise TypeError("dtype must be known for auto-chunking")
#    3168 if dtype.hasobject:
# -> 3169     raise NotImplementedError(
#    3170         "Can not use auto rechunking with object dtype. "
#    3171         "We are unable to estimate the size in bytes of object data"
#    3172     )
#    3174 for x in tuple(chunks) + tuple(shape):
#    3175     if (
#    3176         isinstance(x, Number)
#    3177         and np.isnan(x)
#    3178         or isinstance(x, tuple)
#    3179         and np.isnan(x).any()
#    3180     ):
#
# NotImplementedError: Can not use auto rechunking with object dtype. We are unable to estimate the size in bytes of object data

# %%
plt.figure(2)
ax = plt.axes(projection = ccrs.PlateCarree(central_longitude=-125))  # Orthographic
extent = [lon_min, lon_max,lat_min, lat_max]
#ax.set_extent(extent, crs=ccrs.PlateCarree())


plt.set_cmap(cmap=plt.get_cmap('turbo'))
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, alpha=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False
ax.set_title('Sea Surface Height Anomaly ', size = 10.)

ds = xr.open_dataset(file_list[1])
var = ds.ssha_karin_2 #simulated_true_ssh_karin
#plt.pcolor(ds.longitude, ds.latitude, var)
cs = ax.pcolormesh(ds.longitude,ds.latitude,var,transform=ccrs.PlateCarree())
cb = plt.colorbar(cs,fraction = 0.046,extend='both')
ax.coastlines()
ax.add_feature(cartopy.feature.LAND, zorder=3, facecolor=[.6,.6,.6], edgecolor='black')
#cs = ax.pcolormesh(ds.longitude,ds.latitude,ds.sea_surface_temperature.squeeze()-274.15,vmin=V[0],vmax=V[1],transform=ccrs.PlateCarree())
# cs = ax.pcolormesh(ds2.lon,ds2.lat,ds2.sea_surface_temperature.squeeze().notnull(),transform=ccrs.PlateCarree())
#cb = plt.colorbar(cs,fraction = 0.022,extend='both')
#cb.set_label('SST [$\circ$C]',fontsize = 10)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure(3)
ax = plt.axes(projection = ccrs.PlateCarree(central_longitude=-125))  # Orthographic
extent = [lon_min, lon_max,lat_min, lat_max]
#ax.set_extent(extent, crs=ccrs.PlateCarree())


plt.set_cmap(cmap=plt.get_cmap('turbo'))
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, alpha=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False
ax.set_title('Sea Surface Height Anomaly ', size = 10.)

ds = xr.open_dataset(file_list[2])
var = ds.ssha_karin #simulated_true_ssh_karin
#plt.pcolor(ds.longitude, ds.latitude, var)
cs = ax.pcolormesh(ds.longitude,ds.latitude,var,transform=ccrs.PlateCarree())
cb = plt.colorbar(cs,fraction = 0.046,extend='both')
ax.coastlines()
ax.add_feature(cartopy.feature.LAND, zorder=3, facecolor=[.6,.6,.6], edgecolor='black')
#cs = ax.pcolormesh(ds.longitude,ds.latitude,ds.sea_surface_temperature.squeeze()-274.15,vmin=V[0],vmax=V[1],transform=ccrs.PlateCarree())
# cs = ax.pcolormesh(ds2.lon,ds2.lat,ds2.sea_surface_temperature.squeeze().notnull(),transform=ccrs.PlateCarree())
#cb = plt.colorbar(cs,fraction = 0.022,extend='both')
#cb.set_label('SST [$\circ$C]',fontsize = 10)

# %%
var = ds.simulated_true_ssh_karin #ssha_karin_2 #simulated_true_ssh_karin

plt.figure(4)
plt.pcolor(ds.longitude, ds.latitude, var)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure()
ax = plt.axes(projection = ccrs.PlateCarree(central_longitude=-125))  # Orthographic
extent = [lon_min, lon_max,lat_min, lat_max]
ax.set_extent(extent, crs=ccrs.PlateCarree())

var1 = ds.wind_speed_karin
plt.set_cmap(cmap=plt.get_cmap('turbo'))
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, alpha=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False
ax.set_title('SST', size = 10.)

# Does not do what I think it should:
#ax.minorticks_on()
#ax.tick_params(axis='both',which='both',direction='inout',top=True, right=True)

V=np.array([0,65000])
ax.coastlines()
ax.add_feature(cartopy.feature.LAND, zorder=3, facecolor=[.6,.6,.6], edgecolor='black')
cs = ax.pcolormesh(ds.longitude,ds.latitude,var1,vmin=V[0],vmax=V[1])
cb = plt.colorbar(cs,fraction = 0.027,extend='both')
cb.set_label('Wind Speed [m/s]',fontsize = 10)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ds = xr.open_dataset(file_list[1])

# %%
ds.latitude.plot()
#ds = xr.open_dataset(file_list[0]).sel(longitude=slice(lon_min2,lon_max2), latitude=slice(lat_min,lat_max))

# %%
lon_min2=lon_min+360
lon_max2=lon_max+360
